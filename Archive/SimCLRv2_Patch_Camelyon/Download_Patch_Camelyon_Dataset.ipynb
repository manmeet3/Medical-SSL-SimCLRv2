# %%
import re
import numpy as np

import tensorflow.compat.v2 as tf
tf.compat.v1.enable_v2_behavior()
import tensorflow_hub as hub
import tensorflow_datasets as tfds

import matplotlib
import matplotlib.pyplot as plt

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cd '/content/gdrive/Shareddrives/DL2-project/Datasets/'

# %%
dataset_name = 'patch_camelyon'
data_dir = '/content/gdrive/Shareddrives/DL2-project/Datasets/'

tfds_dataset, tfds_info = tfds.load(
    dataset_name, split='train', with_info=True, data_dir=data_dir)
# Out:
# Downloading and preparing dataset patch_camelyon/2.0.0 (download: 7.48 GiB, generated: Unknown size, total: 7.48 GiB) to /content/gdrive/Shareddrives/DL2-project/Datasets/patch_camelyon/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /content/gdrive/Shareddrives/DL2-project/Datasets/patch_camelyon/2.0.0.incompleteBJH835/patch_camelyon-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=32768.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /content/gdrive/Shareddrives/DL2-project/Datasets/patch_camelyon/2.0.0.incompleteBJH835/patch_camelyon-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=262144.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /content/gdrive/Shareddrives/DL2-project/Datasets/patch_camelyon/2.0.0.incompleteBJH835/patch_camelyon-validation.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=32768.0), HTML(value='')))
# Dataset patch_camelyon downloaded and prepared to /content/gdrive/Shareddrives/DL2-project/Datasets/patch_camelyon/2.0.0. Subsequent calls will reuse this data.
